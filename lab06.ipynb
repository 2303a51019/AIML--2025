# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a51019/AIML--2025/blob/main/lab06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Part 1: Import the required Python, Pandas, Matplotlib, Seaborn packages

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab import files
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c3169cc8-f809-4641-b2fe-83cc73f0be01" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c3169cc8-f809-4641-b2fe-83cc73f0be01">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
a = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Piece_Dimension.csv')

# %%
print("Data Types of Each Feature:")
print(a.dtypes)
# Out:
# Data Types of Each Feature:
# Item_No       int64
# Length      float64
# Width       float64
# Height      float64
# Operator     object
# dtype: object

# %% [markdown]
# Generate a summary of the dataset for min, max, stddev, quartile values for 25%, 50%, 75%, 90%

# %%
print("\nSummary Statistics of the Dataset (including quartiles):")
print(a.describe(percentiles=[.25, .5, .75, .90]))
# Out:
# Summary Statistics of the Dataset (including quartiles):
#           Item_No      Length      Width      Height
# count  500.000000  500.000000  500.00000  500.000000
# mean   250.500000   99.769140   49.93288   20.293220
# std    144.481833    4.107471    2.11382    1.051718
# min      1.000000   87.520000   42.74000   17.370000
# 25%    125.750000   96.835000   48.34000   19.475000
# 50%    250.500000   99.565000   49.82500   20.310000
# 75%    375.250000  102.035000   51.46250   21.142500
# 90%    450.100000  103.945000   52.53100   21.621000
# max    500.000000  116.600000   58.26000   23.390000

# %% [markdown]
# # Get the list of columns (excluding the target and possibly irrelevant columns)

# %%
ls = list(a.columns)
sns.pairplot(a)

# %%
for i in range(len(ls)-1):
  sns.boxplot(x='TARGET_CLASS', y=ls[i], data=a)
  plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-2a5e902a6b64> in <cell line: 1>()
#       1 for i in range(len(ls)-1):
# ----> 2   sns.boxplot(x='TARGET_CLASS', y=ls[i], data=a)
#       3   plt.show()
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1594 ):
#    1595
# -> 1596     p = _CategoricalPlotter(
#    1597         data=data,
#    1598         variables=dict(x=x, y=y, hue=hue),
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in __init__(self, data, variables, order, orient, require_numeric, color, legend)
#      64     ):
#      65
# ---> 66         super().__init__(data=data, variables=variables)
# ...
